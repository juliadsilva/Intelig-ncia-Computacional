# %% [markdown]
# Crie um modelo de agrupamento para os dados do
# arquivo dataset_1.csv, para isto utilize o algoritmo KMeans fornecido pelo
# scikit-learn. O número de grupos deverá ser definido com o método do
# cotovelo (Elbow Method). Utilize de visualizações (gráficos) para apresentar
# sua resposta. Ao final explique brevemente o método do cotovelo.
