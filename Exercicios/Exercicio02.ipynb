# %% [markdown]
# ## Leitura de Dados

# %%
import pandas as pd

# %%
data = pd.read_csv("kc_house_data.csv")

# %% [markdown]
# ## Análise Exploratória

# %%
data.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
data.isna().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %% [markdown]
# ## Visualização

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.dpi"] = 100
plt.scatter( data["sqft_living"], data["price"], color="black")
plt.title("SQFT Living vs Price")
plt.xlabel("SQFT Living")
plt.ylabel("Price")
plt.show()

# %%
import numpy as np

data_x = np.array(list(data["sqft_living"])).reshape(-1,1)
data_y = np.array(list(data["price"])).reshape(-1,1)

# %% [markdown]
# ## Divisão dos dados

# %%
from sklearn.model_selection import train_test_split

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(data_x, data_y, test_size=0.3)

# %%
print("Treino:", len(x_treino))
print("Teste:", len(x_teste))
# Out:
# Treino: 15129
# Teste: 6484

# %% [markdown]
# ## Criação do Modelo

# %%
from sklearn import linear_model

# %%
modelo = linear_model.LinearRegression()
modelo.fit(x_treino,y_treino)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("Coeficiente: ", modelo.coef_)
# Out:
# Coeficiente:  [[287.6892724]]

# %% [markdown]
# ## Predições

# %%
y_predicao = modelo.predict(x_teste)

# %%
plt.scatter(x_teste, y_predicao, color="red", edgecolors="black")
plt.scatter(x_teste, y_teste, color="blue")
plt.plot(x_teste, y_predicao, color="red", linewidth=2)
plt.show()

# %% [markdown]
# ## Métricas de Avaliação

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_teste, y_predicao)

# %%
print("MSE: ", mse)
# Out:
# MSE:  64715750319.07062
