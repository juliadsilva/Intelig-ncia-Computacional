# %% [markdown]
# 1. Inicialize a população de cromossomos;
# 2. Avalie cada cromossomo na  populaçã
# 3. Selecione os pais para gerar novos cromossomos
# Escrever depois

# %% [markdown]
# Fenotipo -> base 10
# Genotipo -->  binario

# %%
import random
import numpy as np

# %%
class Bitset: 
  def _init_(self,size)
    self.bits = np.pull((1, False, Falso))

  def get()
# Out:
#   File "<ipython-input-3-6f5b2b75d3a2>", line 2
#     def _init_(self,size)
#                          ^
# SyntaxError: invalid syntax
